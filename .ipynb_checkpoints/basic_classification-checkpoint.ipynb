# %% [markdown]
# # Train your first neural network: basic classification

# %% [markdown]
# Training a neural network model to classify images of clothing using `tf.keras`

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 1.12.0

# %% [markdown]
# ## Import the Fashion MNIST dataset

# %% [markdown]
# **Fashion MNIST dataset**
# - Contains 70,000 grascale images in 10 categories
# - The images how indicidual articles of clothing at low resolution (28 x 28)

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# The dataset returns four NumPy arrays:
# - The `train_images` and `train_labels` arrays are the training set -- the data the model uses to learn
# - The model is tested against the test set, the `test_images` and `test_labels` arrays

# %%
# classes in mnist dataset
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ## Explore the data

# %% [markdown]
# - 60,000 images in the training images set, and 28 x 28 represents pixels of each image
# - 60,000 labels in the training labels set
# - Training label set consists of 60,000 integers from 0 to 9 (9 classes)
# - 10,000 images in the test images set
# - 10,000 labels in the test labels set

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %% [markdown]
# ## Process the data

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)

# %% [markdown]
# - Scale these values to a range of 0 to 1 before feeding to the neural network model
# - Make sure the training set and the testing set are preprocessed in the same way

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# - Display the first 25 images from the training set and display the class name below each image
# - Verify the data is in the correct format

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])

# %% [markdown]
# ## Build the model

# %% [markdown]
# - Configure the layers of the model
# - Compile the model

# %% [markdown]
# ### Setup the layers

# %% [markdown]
# - Layer is the basic building block of the neural network
# - Layer extract representations from the data fed into them

# %% [markdown]
# - Most of depp learning consists of chaining together simple layers

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %% [markdown]
# `tf.keras.layers.Flatten`
# - Transforms the format of images from a 2d-array (28x28 pixels), to a 1d-array of 28 * 28 = 784 pixels
# - This layer is like an unstacking rows of pixels in the image and lining them up
# - No parameters to learn, and only reformats the data

# %% [markdown]
# `tf.keras.layers.Dense`
# - Densely connected (fully connected) neural layers
# - The first `Dense` layer has 128 nodes (or neurons)
# - The second `Dense` layer is a 10-node *softmax* layer -- this returns an array of 10 probability scores that sum to 1
# - Each node contains a score that indicates the probability that the current image belongs to one of the 10 classes

# %% [markdown]
# ### Compile the model

# %% [markdown]
# - Before the model is ready for training, it needs a few more settings
# - These are added during the model's *compile* step

# %% [markdown]
# *Loss function*
# - This measures how accurate the model is during training
# - We want to minimize this function to "steer" the model in the right direction
#
# *Optimizer*
# - This is how the model is updated based on the data it sees and its loss function
#
# *Metrics*
# - Used to monitor the training and testing steps.
# - The following example uses accuracy, the fraction of the images that are correctly classified

# %%
model.compile(optimizer=tf.train.AdamOptimizer(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Train the model

# %% [markdown]
# Training the neural network model requires the following steps:
# 1. Feed the training data to the model -- in this example, the `train_images` and `train_labels` array
# 2. The model learns to associate images and labels
# 3. We ask the model to make predictions about a test set -- in this example, the `test_images` array. We verify that the predictions match the labels from the `test_labels` array
#
# To start training, call the `model.fit` method -- the model is "fit" to the training data:

# %%
model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.5016 - acc: 0.8244
# Epoch 2/5
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.3756 - acc: 0.8651
# Epoch 3/5
# 60000/60000 [==============================] - 6s 98us/step - loss: 0.3404 - acc: 0.8766
# Epoch 4/5
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.3163 - acc: 0.8845
# Epoch 5/5
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.2985 - acc: 0.8888

# %% [markdown]
# As the model trains, the loss and accuracy metrics are displayed. This model reaches an accuracy of 0.91 on the training data.

# %% [markdown]
# ### Evaluate accuracy

# %% [markdown]
# - Compare how the model performs on the test dataset

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 0s 32us/step
# Test accuracy: 0.8724

# %% [markdown]
# - The gap between training accuracy and test accuracy is an example of *overfitting*
# - Overfitting is when a machine learning model performs worse on new data than on their training data

# %% [markdown]
# ### Make predictions

# %%
predictions = model.predict(test_images)

# %%
predictions[0]
# Out:
# array([4.5041437e-05, 1.2314811e-08, 1.7924287e-06, 1.0645823e-07,
#        2.3420166e-06, 9.9343862e-03, 1.0505858e-06, 2.3702916e-02,
#        1.8145141e-04, 9.6613085e-01], dtype=float32)

# %% [markdown]
# - A prediction is an array of 10 numbers
# - These describe the "confidence" of the model that the image corresponds to to each of the 10 different articles of clothing

# %%
class_names[np.argmax(predictions[0])] == class_names[test_labels[0]]
# Out:
# True

# %%
def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
  
    plt.imshow(img, cmap=plt.cm.binary)

    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
        color = 'blue'
    else:
        color = 'red'

    plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                  100*np.max(predictions_array),
                                  class_names[true_label]),
                                  color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    thisplot = plt.bar(range(10), predictions_array, color="#777777")
    plt.ylim([0, 1]) 
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[true_label].set_color('blue')

# %% [markdown]
# The prediction of the 0th image:

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions,  test_labels)

# %%
i = 12
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions,  test_labels)

# %% [markdown]
# - Correct predictions are blue and incorrect predictions are red
# - The number gives the precent (out of 100) for the predicted label

# %%
# Plot the first X test images, their predicted label, and the true label
# Color correct predictions in blue, incorrect predictions in red
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2*num_cols, 2*i+1)
    plot_image(i, predictions, test_labels, test_images)
    plt.subplot(num_rows, 2*num_cols, 2*i+2)
    plot_value_array(i, predictions, test_labels)

# %% [markdown]
# We use trained model to make a prediction about a single image:

# %%
# Grab an image from the test dataset
img = test_images[0]
print(img.shape)
# Out:
# (28, 28)

# %% [markdown]
# `tf.keras` models are optimized to make predictions on a *batch*, or collection, of examples at once. So even though we're using a single image, we need to add it to a list:

# %%
# Add the image to a batch where it's the only member
img = (np.expand_dims(img, 0))
print(img.shape)
# Out:
# (1, 28, 28)

# %% [markdown]
# Now predict the image:

# %%
predictions_single = model.predict(img)
print(predictions_single)
# Out:
# [[4.5041481e-05 1.2314811e-08 1.7924303e-06 1.0645844e-07 2.3420166e-06
#   9.9343946e-03 1.0505898e-06 2.3702927e-02 1.8145141e-04 9.6613085e-01]]

# %%
plot_value_array(0, predictions_single, test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)

# %% [markdown]
# `model.predict` returns a list of lists, one for each image in the batch of data. Grab the predictions for our image in the batch:

# %%
np.argmax(predictions_single[0])
# Out:
# 9
